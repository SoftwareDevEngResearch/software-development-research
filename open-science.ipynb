# %% [raw]
# ---
# title: "Open science, software citation, reproducibility best practices"
# author: "Kyle Niemeyer"
# date: "5 March 2025"
# institute: "Oregon State University"
# format:
#   revealjs:
#     output-file: open-science-revealjs.html
#     incremental: true
#     fig-align: center
#     fig-responsive: true
#     toc: false
#     code-block-height: 650px
#   html: default
# jupyter: python3
# highlight-style: arrow
# execute:
#   echo: true
# ---

# %% [markdown]
# # Topics
#
# - Software archival
# - Software citation
# - Venues for sharing and publication
# - Best practices for reproducibility
#
# # Open science best practices
#
# ##
#
# ::: fragment
# Sharing software and data openly has clear benefits to other *and* yourself.
# :::
#
# ::: fragment
# A paper that isn’t accompanied by the software or data produced is just **advertising**. ([Claerbout & Karrenbach, 1992](http://sepwww.stanford.edu/doku.php?id=sep:research:reproducible:seg92))
# :::
#
# ::: fragment
# People find reproducible results more trustworthy…
# :::
#
# ::: fragment
# …and cite you more! ([Piwowar & Vision, 2013](https://doi.org/10.7717/peerj.175))
# :::
#
# ::: fragment
# Reduce duplicated effort and increase impact.
# :::
#
# ## Open source software
#
# We've talked about:
#
# - environment management
# - version control
# - licensing
# - documentation
# - testing
# - packaging and distribution
# - software design practices
# - optimizing code
#
# ## Great! All done? {.nostretch}
#
# ::: fragment
# ![](./images/stop-sign.png){width="30%"}
# :::
#
# ::: fragment
# For research, we need one more step: **archival** of software and/or data.
# :::
#
# ::: fragment
# Consider: what if you cite this, then someone modifies or deletes it?
# :::
#
# ## Archiving
#
# ![](./images/archiving.png)
#
# ## Live demo: connect GitHub to Zenodo
#
# ::: fragment
# ![](./images/live-demo-meme.jpeg)
# :::

# %% [markdown]
# # Software citation
#
# ## Modern science and engineering research depend on software.
#
# ::: fragment
# 2009 survey: 91% of scientists consider software “important” or “very important” to research. ([Hannay et al. 2009](https://doi.org/10.1109/SECSE.2009.5069155))
# :::
#
# ::: fragment
# But, 40–70% of software used is not cited. ([Pan et al. 2015](https://doi.org/10.1016/j.joi.2015.07.012), [Howison et al. 2016](https://doi.org/10.1002/asi.23538))
# :::
#
# ## Citing software & data is important.
#
# ::: fragment
# Our research results depend on software and data—different versions of software and data changes our answers.
# :::
#
# ::: fragment
# Without proper citations, your work is not reproducible.
# :::
#
# ::: fragment
# Also, academia relies on citations for credit. (for better or worse)
# :::
#
# ## Software citation principles
#
# ![](./images/software-citation-paper.png)
#
# Smith AM, Katz DS, Niemeyer KE, FORCE11 Software Citation Working Group. (2016) Software citation principles. *PeerJ Computer Science* 2:e86 [https://doi.org/10.7717/peerj-cs.86](https://doi.org/10.7717/peerj-cs.86)
#
# ##
#
# ![](./images/software-citation-principles.png)
#
# ## Software citation principles
#
# (@) **Importance**: software as important as other research products
# (@) **Credit & attribution**: citations should facilitate scholarly credit and attribution to all contributors
# (@) **Unique identification**: citation should include machine actionable, globally unique, interoperable, and recognized identification method
#
# ## Software citation principles
#
# (@) **Persistence**: Unique identifiers and metadata should persist
# (@) **Accessibility**: Citations should facilitate access to software and associated metadata
# (@) **Specificity**: Citations should facilitate identification of, and access to, specific version of software used
#
# ## How to cite?
#
# ::: {.fragment fragment-index=1}
# Name/description
# :::
#
# ::: {.fragment fragment-index=2}
# Authors/developers
# :::
#
# ::: {.fragment .fade-in fragment-index=3}
# ::: {.fragment .semi-fade-out fragment-index=4}
# DOI or other unique/persistent identifier
# :::
# :::
#
# ::: {.fragment fragment-index=4}
# Version number/commit hash
# :::
#
# ::: {.fragment fragment-index=5}
# Location (e.g., GitHub repo)
# :::
#
# ::: {.fragment fragment-index=6}
# (If there’s a paper describing it, cite that *too*.)
# :::
#
# ## Where to cite? {.smaller}
#
# ::: fragment
# In the text with the references/bibliography.
# :::
#
# :::: {.columns .fragment}
#
# ::: {.column width="50%"}
# ![](./images/paper-snip1.png){width="90%"}
#
# KE Niemeyer, “PyTeCK: a Python-based automatic testing package for chemical kinetic models”. *Proceedings of SciPy 2016*. [https://doi.org/10.25080/Majora-629e541a-00c](https://doi.org/10.25080/Majora-629e541a-00c)
# :::
#
# ::: {.column width="50%"}
# ![](./images/pyjac-paper.png){width="90%"}
#
# KE Niemeyer, NJ Curtis, & CJ Sung. “pyJac: analytical Jacobian generator for chemical kinetics” (2017) *Computer Physics Communications*, 215:188–203.
# [https://doi.org/10.1016/j.cpc.2017.02.004](https://doi.org/10.1016/j.cpc.2017.02.004)
# :::
#
# ::::

# %% [markdown]
# # Publishing your software {.smaller}
#
# ::: fragment
# You've put all this effort into crafting your research software following best practices. How to get academic credit for this?
# :::
#
# - Mention in research article
# - Submit to domain-specific software journal: *Computer Physics Communications*, *ACM Transactions on Mathematical Software*, *Journal of Statistical Software*, *Nature Methods*, *Geoscientific Model Development*
# - Archive independently
# - Submit to *Journal of Open Source Software*
#
# ## Journal of Open Source Software (JOSS) {.smaller}
#
# :::: {.columns}
#
# ::: {.column width="70%"}
# - <https://joss.theoj.org>
# - Developer-friendly journal for research software packages
# - Affiliate of [Open Source Initiative](https://opensource.org/)
# - Open access, no fees: [diamond/platinum open access journal](https://en.wikipedia.org/wiki/Open_access#Diamond/platinum_OA)
# :::
#
# ::: {.column width="30%"}
# ![](https://raw.githubusercontent.com/openjournals/digital-assets/master/joss/logo/JOSS_1000x1000.png)
# :::
#
# ::::
#
# ::: fragment
# > “If you've already licensed your code and have good documentation then we expect that it should take less than an hour to prepare and submit your paper to JOSS.”
#
# :::
#
# ##
#
# ![](./images/JOSS-flowchart-updated.png)
#
# ## JOSS paper submission
#
# ![](./images/joss-submission.png)
#
# ## JOSS paper reviews
#
# ![](./images/joss-reviews.png)
#
# ## JOSS review
#
# ![](./images/joss-paper-review.png)

# %% [markdown]
# # Reproducibility best practices
#
# ## "Repro-packs" {.smaller}
#
# Lorena Barba describes [“reproducibility packages”](http://blogs.nature.com/naturejobs/2017/04/17/techblog-my-digital-toolbox-lorena-barba/) associated with papers, sharing figures under CC-BY:
#
# > “For every figure that presents some result, we bundle the files needed to reproduce it — input or configuration files used to run the simulation(s) behind the result; code to process raw data into derived data; and scripts to create output graphs — and deposit them together with the figure into an open-data repository, such as Figshare. Figshare assigns the bundle a DOI, which we then include in the figure caption so readers can easily find the data and re-create the result. Our lab uses these packages as test beds for our in-house software, to verify that the results haven’t been compromised by software modifications. And because we maintain a public history of all changes, we achieve what one of my students calls ‘unimpeachable provenance’.”
#
# ## My repro-pack practice
#
# 1. Produce a single “repro-pack” for an entire paper, which contains:
#   - Python plotting scripts and associated results data
#   - Figures (PDFs for plots, always)
#   - Any other relevant data: input files, configuration files, etc.
# 2. Upload to Zenodo under CC-BY license
# 3. Cite using the resulting DOI in the associated paper(s)
#
# ## Benefits
#
# - Improving reproducibility and impact of your work
# - Reviewers will love you with this one great trick!
# - It also lets you reuse your figures without violating the journal copyright. (Yes, when published, the journal owns the paper and everything in it that isn’t licensed from somewhere else.)
#
# ## How to cite/mention {.smaller}
#
# :::: {.columns}
#
# ::: {.column width="50%"}
# ![](images/repropack-reference.png)
#
# ![](images/repropack-citation.png)
#
# CP Stone, AT Alferman, & KE Niemeyer. 2018. “Accelerating finite-rate chemical kinetics with coprocessors: comparing vectorization methods on GPUs, MICs, and CPUs.” *Computer Physics Communications*, 226:18–29. [https://doi.org/10.1016/j.cpc.2018.01.015](https://doi.org/10.1016/j.cpc.2018.01.015)
# :::
#
# ::: {.column width="50%"}
# ![](images/behnoudfar-PoF-repropack.png)
#
# ![](images/behnoudfar-PoF-citations.png)
#
# D Behnoudfar & KE Niemeyer. 2025. “A single-domain approach for
# modeling flow in and around porous media applied to buoyant reacting plume formation
# and ignition.” *Physics of Fluids*, 37:012111. [https://doi.org/10.1063/5.0248978](https://doi.org/10.1063/5.0248978)
# :::
#
# ::::
#
# ##
#
# ![](images/repropack-file-layout.png)
#
# ## Best practice example
#
# - Source code at [github.com/SLACKHA/pyJac](https://github.com/SLACKHA/pyJac) has `README` with basic usage
# - Full documentation website with API docs, installation guide, and examples: [slackha.github.io/pyJac/](https://slackha.github.io/pyJac/)
# - Functional and performance testing suites built-in
# - Software paper published with full theory details ([https://doi.org/10.1016/j.cpc.2017.02.004](https://doi.org/10.1016/j.cpc.2017.02.004))
# - full source of paper also available via [niemeyer-research-group.github.io/pyJac-paper/](niemeyer-research-group.github.io/pyJac-paper/)
# - Data, figures, and figure scripts from paper available openly via Figshare: [https://doi.org/10.6084/m9.figshare.4578010](https://doi.org/10.6084/m9.figshare.4578010)

# %% [markdown]
# # Publishing and open access
#
# ## Open-access journals
#
# :::: {.columns}
#
# ::: {.column width="50%"}
# ![](./images/goldOA.png)
# :::
#
# ::: {.column width="50%"}
# Open Access (OA)
#
# ::: fragment
# Meaning: research output that is free to access/read
# :::
#
# :::
# ::::
#
# ## Types of open access
#
# :::: {.columns}
#
# ::: {.column width="50%" .fragment}
# ![](./images/greenOA.png)
#
# Green OA
#
# self archiving
# :::
#
# ::: {.column width="50%" .fragment}
# ![](./images/goldOA.png)
#
# Gold OA
#
# open access journal
# :::
# ::::
#
# ## Gold OA
#
# ::: fragment
# Either fully open journal (ok) or hybrid (bad).
# :::
#
# ::: fragment
# Typically—though not always—both require article processing charge (APC).
# :::
#
# ::: fragment
# [Oregon State University Library program](https://guides.library.oregonstate.edu/c.php?g=285945&p=5909778) covers fees for *PeerJ* journals.
# :::
#
# ## Green OA
#
# ::: fragment
# Meaning: publish in traditional (closed) venue, but also make available openly.
# :::
#
# ::: fragment
# Where? eprint/preprint archives.
# :::
#
# :::: {.columns}
# ::: {.column width="25%" .fragment}
# ![](./images/arxiv-logo.jpg)
# :::
# ::: {.column width="25%" .fragment}
# ![](./images/engrxiv-logo.png)
# :::
# ::: {.column width="25%" .fragment}
# ![](./images/zenodo-logo.png)
# :::
# ::: {.column width="25%" .fragment}
# ![](./images/scholars-archive.png)
# :::
# ::::
#
# ## OSU Open Access policy
#
# Oregon State has an [Open Access policy](https://library.oregonstate.edu/open-access):
#
# > In recognition of Oregon State University’s land-grant mission, the Faculty is committed to disseminating its research and scholarship as widely as possible. In addition to the public benefit of such dissemination, this policy is intended to serve faculty interests by promoting greater reach and impact for articles. The policy directs faculty to submit an electronic copy of the author's accepted (post-peer review, pre-typeset) manuscript of their articles to OSU Libraries for dissemination via the [ScholarsArchive@OSU](http://ir.library.oregonstate.edu/) institutional repository.
#
# ##
#
# :::: {.columns}
# ::: {.column width="43%"}
# ![](./images/behnoudfar-PoF-journal.png)
# Journal version
# :::
# ::: {.column width="50%"}
# ![](./images/behnoudfar-PoF-arxiv.png)
#
# Author-accepted version
# :::
# ::::
#
# ##
#
# ::: {.callout-warning}
# Don't post the journal version of a paper online!
# :::
#
# ::: fragment
# In general when publishing an article, you transfer copyright of the content
# to the journal.
# :::
#
# ::: fragment
# Protect yourself by self-archiving the author-accepted text and figures (via a repropack!).
# :::

# %% [markdown]
# # Questions?
